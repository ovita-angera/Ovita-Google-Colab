# %% [markdown]
# <a href="https://colab.research.google.com/github/ovita-angera/Ovita-Google-Colab/blob/main/ReadXLSXFiles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This file explores the use of pandas in reading an excel file with multiple worksheets.

# %%
# import the necessary library
import pandas as pd

# %%
# define the file path and use the file path in reading the separate worksheets of interest
file_path = "./Origins.xlsx"

_file = pd.ExcelFile(file_path)
_file

# %%
# check which sheets are present in the file which has been read into our programming env
_file.sheet_names
# Out:
# ['One', 'Two']

# %%
student_scores = pd.read_excel(_file, "Two")

# %%
student_scores
# Out:
#    Row id First Name   Last Name  Mid  End  Aggr. Grade
# 0       1      Brian        Vitz   85   90  88.75     A
# 1       2      Lenny     Kravitz   92   89  89.75     A
# 2       3    Brienne        Olaf   98   98  98.00     A
# 3       4      Alice       Smith   78   92  88.50     A
# 4       5      Hosea    Lakewood   88   76  79.00    B+
# 5       6     George    Sellwing   98   60  69.50    B+
# 6       7     Regina  Vanhelsing   78   89  86.25    A-
# 7       8     Robert      Dinero   68   99  91.25     A
# 8       9    Houston    Banderas   90   75  78.75    B+
# 9      10      Faith       Stark   82   67  70.75    B+
